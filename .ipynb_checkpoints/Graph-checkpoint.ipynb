# %%
myfile = open("Q1b.out")
data = []
for line in myfile:
    data.append(line)
myfile.close()

# %%
time = []
core = []
for val in data:
    val = val.split()
    time.append(float(val[0]))
    core.append(float(val[1]))

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(core, time)
plt.title("Simulation Time on Using Different Cores")
plt.xlabel("Number of Cores")
plt.ylabel("Seconds")
plt.savefig("Q1b.png")

# %% [markdown]
# The speed up is not linear because the running time of using 1 core is already very low, there is not much potential to decrease the running time. In addition to that, running on mutiple cores require inter-connection between each core to share their results, which could delay the whole process.

# %%
myfile = open("Q2b.out")
data = []
for line in myfile:
    data.append(line)
myfile.close()

# %%
period = []
rhos = []
for i, row in enumerate(data):
    if i == 199:
        ts = row.split()[1:]
        period.append(float(ts[0]))
        rhos.append(float(ts[1][:-2]))
    else:
        ts = row.split()[1:]
        period.append(float(ts[0]))
        rhos.append(float(ts[1][:-1]))

# %%
plt.scatter(rhos, period)
plt.title("Living Period on Using Different Rhos")
plt.xlabel("Rhos")
plt.ylabel("Periods")
plt.savefig("Q2b.png")

# %% [markdown]
# The computation time I get is 0.9862573146820068 seconds, the optimal rho is -0.03341708542713573 and the average living period is 754.757
